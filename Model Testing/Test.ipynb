# %%
import os
import time
import numpy as np
from sklearn.metrics import accuracy_score
from ultralytics import YOLO

# Load the trained model (replace "best_model.pt" with the path to your best model's weights)
model = YOLO(r"C:\Users\dunli\Documents\STSY-project-main\Model Training\runs\detect\train16\weights\best.pt")

# Path to test images directory
test_images_dir = r"C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images"

# Output directory for processed images
output_dir = r"C:\Users\dunli\Documents\STSY-project-main\Results\new_tested_image"

# Check if the directory exists, if not, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Check if the test images directory exists
if not os.path.exists(test_images_dir):
    raise FileNotFoundError(f"The directory '{test_images_dir}' does not exist.")

# Initialize lists to store ground truth labels and predicted labels
ground_truth_labels = []
predicted_labels = []

# Measure processing time
start_time = time.time()

# Iterate through each image in the test directory
for image_file in os.listdir(test_images_dir):
    image_path = os.path.join(test_images_dir, image_file)
    # Perform inference on the image
    results = model(image_path)
    # Iterate through each result
    for result in results:
        # Save the processed image to the output directory
        output_image_path = os.path.join(output_dir, image_file)
        result.save(output_image_path)
        ground_truth_label = image_file.split("_")[0]  # Extracting label from file name
        ground_truth_labels.append(ground_truth_label)
        # Extract predicted label from the result
        predicted_label = result.names[0] if len(result.boxes) > 0 else "None"
        predicted_labels.append(predicted_label)

# Calculate processing time
processing_time = time.time() - start_time

# Print processing time
print("Processing Time:", processing_time, "seconds")
# Out:
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_15_1.png: 640x640 9 rods, 1 microcolony, 26.5ms
# Speed: 13.6ms preprocess, 26.5ms inference, 165.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_15_2.png: 640x640 16 rods, 27.6ms
# Speed: 2.7ms preprocess, 27.6ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_15_3.png: 640x640 15 rods, 4 microcolonys, 27.9ms
# Speed: 2.7ms preprocess, 27.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_15_4.png: 640x640 14 rods, 27.4ms
# Speed: 2.7ms preprocess, 27.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_55_1.png: 640x640 9 rods, 2 microcolonys, 27.6ms
# Speed: 2.3ms preprocess, 27.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_55_2.png: 640x640 20 rods, 27.6ms
# Speed: 3.4ms preprocess, 27.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_55_3.png: 640x640 14 rods, 5 microcolonys, 27.6ms
# Speed: 2.8ms preprocess, 27.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_55_4.png: 640x640 16 rods, 1 microcolony, 27.0ms
# Speed: 1.7ms preprocess, 27.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_80_1.png: 640x640 6 rods, 5 microcolonys, 25.0ms
# Speed: 2.7ms preprocess, 25.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_80_2.png: 640x640 4 rods, 9 microcolonys, 24.3ms
# Speed: 2.2ms preprocess, 24.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_80_3.png: 640x640 4 rods, 7 microcolonys, 24.9ms
# Speed: 2.7ms preprocess, 24.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_frame_80_4.png: 640x640 5 rods, 7 microcolonys, 24.0ms
# Speed: 2.7ms preprocess, 24.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_fr_1_1.png: 640x640 8 rods, 24.8ms
# Speed: 3.4ms preprocess, 24.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_fr_1_2.png: 640x640 11 rods, 25.0ms
# Speed: 2.2ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_fr_1_3.png: 640x640 14 rods, 3 microcolonys, 25.2ms
# Speed: 2.2ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_fr_1_4.png: 640x640 9 rods, 23.9ms
# Speed: 2.6ms preprocess, 23.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_fr_30_1.png: 640x640 9 rods, 2 microcolonys, 24.3ms
# Speed: 3.2ms preprocess, 24.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_fr_30_2.png: 640x640 17 rods, 25.5ms
# Speed: 2.3ms preprocess, 25.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_fr_30_3.png: 640x640 17 rods, 4 microcolonys, 25.3ms
# Speed: 2.1ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_4_fr_30_4.png: 640x640 16 rods, 24.1ms
# Speed: 2.6ms preprocess, 24.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_15_1.png: 640x640 11 rods, 2 microcolonys, 24.9ms
# Speed: 2.7ms preprocess, 24.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_15_2.png: 640x640 5 rods, 1 microcolony, 25.1ms
# Speed: 2.6ms preprocess, 25.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_15_3.png: 640x640 11 rods, 1 microcolony, 24.5ms
# Speed: 2.7ms preprocess, 24.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_15_4.png: 640x640 11 rods, 25.1ms
# Speed: 2.8ms preprocess, 25.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_1_1.png: 640x640 11 rods, 1 microcolony, 24.2ms
# Speed: 2.8ms preprocess, 24.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_1_2.png: 640x640 7 rods, 25.8ms
# Speed: 2.7ms preprocess, 25.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_1_3.png: 640x640 9 rods, 1 microcolony, 25.7ms
# Speed: 2.1ms preprocess, 25.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_1_4.png: 640x640 10 rods, 24.9ms
# Speed: 3.3ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_30_1.png: 640x640 10 rods, 3 microcolonys, 26.2ms
# Speed: 3.9ms preprocess, 26.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_30_2.png: 640x640 7 rods, 1 microcolony, 24.4ms
# Speed: 2.7ms preprocess, 24.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_30_3.png: 640x640 12 rods, 1 microcolony, 25.3ms
# Speed: 2.2ms preprocess, 25.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_30_4.png: 640x640 16 rods, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_55_1.png: 640x640 11 rods, 2 microcolonys, 24.5ms
# Speed: 2.7ms preprocess, 24.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_55_2.png: 640x640 7 rods, 1 microcolony, 25.1ms
# Speed: 2.2ms preprocess, 25.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_55_3.png: 640x640 8 rods, 3 microcolonys, 24.9ms
# Speed: 2.2ms preprocess, 24.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_55_4.png: 640x640 14 rods, 3 microcolonys, 25.5ms
# Speed: 2.2ms preprocess, 25.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_80_1.png: 640x640 2 rods, 7 microcolonys, 24.1ms
# Speed: 2.7ms preprocess, 24.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_80_2.png: 640x640 5 rods, 3 microcolonys, 24.3ms
# Speed: 3.3ms preprocess, 24.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_80_3.png: 640x640 5 rods, 7 microcolonys, 24.7ms
# Speed: 3.4ms preprocess, 24.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_6_frame_80_4.png: 640x640 6 rods, 6 microcolonys, 24.9ms
# Speed: 2.2ms preprocess, 24.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_15_1.png: 640x640 15 rods, 4 microcolonys, 24.6ms
# Speed: 2.8ms preprocess, 24.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_15_2.png: 640x640 12 rods, 3 microcolonys, 25.2ms
# Speed: 2.2ms preprocess, 25.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_15_3.png: 640x640 13 rods, 3 microcolonys, 24.1ms
# Speed: 3.3ms preprocess, 24.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_15_4.png: 640x640 17 rods, 25.1ms
# Speed: 2.3ms preprocess, 25.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_1_1.png: 640x640 18 rods, 24.7ms
# Speed: 2.6ms preprocess, 24.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_1_2.png: 640x640 16 rods, 1 microcolony, 25.0ms
# Speed: 3.3ms preprocess, 25.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_1_3.png: 640x640 13 rods, 2 microcolonys, 25.2ms
# Speed: 2.2ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_1_4.png: 640x640 15 rods, 24.5ms
# Speed: 3.3ms preprocess, 24.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_30_1.png: 640x640 12 rods, 4 microcolonys, 24.5ms
# Speed: 2.6ms preprocess, 24.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_30_2.png: 640x640 16 rods, 3 microcolonys, 24.6ms
# Speed: 2.8ms preprocess, 24.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_30_3.png: 640x640 20 rods, 2 microcolonys, 24.3ms
# Speed: 2.2ms preprocess, 24.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_30_4.png: 640x640 16 rods, 1 microcolony, 25.4ms
# Speed: 2.7ms preprocess, 25.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_55_1.png: 640x640 9 rods, 5 microcolonys, 25.6ms
# Speed: 3.5ms preprocess, 25.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_55_2.png: 640x640 14 rods, 4 microcolonys, 25.7ms
# Speed: 2.1ms preprocess, 25.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_55_3.png: 640x640 13 rods, 5 microcolonys, 25.8ms
# Speed: 2.2ms preprocess, 25.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_55_4.png: 640x640 16 rods, 4 microcolonys, 24.4ms
# Speed: 2.6ms preprocess, 24.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_80_1.png: 640x640 6 rods, 9 microcolonys, 25.0ms
# Speed: 2.6ms preprocess, 25.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_80_2.png: 640x640 14 rods, 5 microcolonys, 24.9ms
# Speed: 3.5ms preprocess, 24.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_80_3.png: 640x640 1 rod, 11 microcolonys, 24.8ms
# Speed: 2.7ms preprocess, 24.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\dunli\Documents\STSY-project-main\Training Data\Original Data\test_images\pos_8_frame_80_4.png: 640x640 5 rods, 7 microcolonys, 25.4ms
# Speed: 2.7ms preprocess, 25.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Processing Time: 4.345182418823242 seconds
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
